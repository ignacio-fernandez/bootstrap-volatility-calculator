# %%
import pandas as pd

# %%
# %pwd
# Out:
# '/home/manel/FinancialProgramming/lectures/13_STL/code/implied_vol'

# %%
# !../build/implied_vol/price_option ../data/options.csv ../data/discounts.csv ../data/forwards.csv ../data/volatilities0.csv > ../data/option_prices0.csv

# %%
data=pd.read_csv("../data/option_prices0.csv")
data
# Out:
#    underlying currenty  notional is_call      expiry    strike      value
# 0         SPX      USD         1     Put  2022-12-22   4000.00   126.5050
# 1         SPX      USD         1     Put  2023-01-22   4000.00   159.5840
# 2         SPX      USD         1     Put  2023-02-22   4000.00   185.3370
# 3         SPX      USD         1    Call  2023-06-22   4000.00   326.9500
# 4         SPX      USD         1    Call  2023-12-22   4000.00   453.8900
# 5         RTY      USD         1     Put  2022-12-22   1882.74    73.3019
# 6         RTY      USD         1     Put  2023-01-22   1882.74    92.8706
# 7         RTY      USD         1     Put  2023-02-22   1882.74   108.1280
# 8         RTY      USD         1    Call  2023-06-22   1882.74   195.6300
# 9         RTY      USD         1    Call  2023-12-22   1882.74   271.5400
# 10        NDX      USD         1     Put  2022-12-22  11330.00   544.2950
# 11        NDX      USD         1     Put  2023-01-22  11330.00   677.7350
# ...

# %%
data2=data.sample(frac=1)
data2
# Out:
#    underlying currenty  notional is_call      expiry    strike      value
# 19        NKY      JPY         1    Call  2023-12-22  28265.00  2472.3500
# 18        NKY      JPY         1    Call  2023-06-22  28265.00  1834.3800
# 9         RTY      USD         1    Call  2023-12-22   1882.74   271.5400
# 16        NKY      JPY         1     Put  2023-01-22  28265.00  1069.2600
# 0         SPX      USD         1     Put  2022-12-22   4000.00   126.5050
# 13        NDX      USD         1    Call  2023-06-22  11330.00  1299.3300
# 10        NDX      USD         1     Put  2022-12-22  11330.00   544.2950
# 12        NDX      USD         1     Put  2023-02-22  11330.00   783.7130
# 15        NKY      JPY         1     Put  2022-12-22  28265.00   829.6860
# 1         SPX      USD         1     Put  2023-01-22   4000.00   159.5840
# 8         RTY      USD         1    Call  2023-06-22   1882.74   195.6300
# 2         SPX      USD         1     Put  2023-02-22   4000.00   185.3370
# ...

# %%
data2.to_csv("../data/option_prices.csv",index=False)
